# %%
import pandas as pd
import dask.dataframe as dd
from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# ### Getting data
# To get data run `data_download.sh`

# %%
data_location = list(filter(lambda x: x.suffix == ".parquet", Path("../data/").iterdir()))

# %%
# Load yellow_cabs_2019 to pandas
# we can get memory errors if we load to the list
# and multiple contacts are super slow!!!
# no way to nicely share data
yellow_cabs_2019 = pd.DataFrame()
months = []
for x in tqdm(data_location[:2]):
    months.append(pd.read_parquet(x))
yellow_cabs_2019 = pd.concat(months)
yellow_cabs_2019.head()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.36it/s]
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-12-01 00:26:58   2019-12-01 00:41:45              1.0
# 1         1  2019-12-01 00:12:08   2019-12-01 00:12:14              1.0
# 2         1  2019-12-01 00:25:53   2019-12-01 00:26:04              1.0
# 3         1  2019-12-01 00:12:03   2019-12-01 00:33:19              2.0
# 4         1  2019-12-01 00:05:27   2019-12-01 00:16:32              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            4.2         1.0                  N           142           116
# 1            0.0         1.0                  N           145           145
# 2            0.0         1.0                  N           145           145
# 3            9.4         1.0                  N           138            25
# ...

# %%
ddf = dd.read_parquet(data_location)

# %%
sales_sum = ddf["total_amount"].sum()
sales_sum.compute()
# Out:
# 1623638298.64
